# %%
import matplotlib.pyplot as plt
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.
# /home/bitai/sw/bitai/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bitai/sw/bitai/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bitai/sw/bitai/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import numpy as np
from sklearn.datasets import make_classification
X, y = make_classification(n_samples = 300,n_features=10,n_classes=2)

# %%
from keras.models import Sequential
model = Sequential()
# Out:
# WARNING:tensorflow:From /home/bitai/sw/bitai/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from keras.layers import Dense, Activation
model.add(Dense(20, activation='tanh', input_dim=10))
# Out:
# WARNING:tensorflow:From /home/bitai/sw/bitai/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/bitai/sw/bitai/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.add(Dense(40, activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy')
# Out:
# WARNING:tensorflow:From /home/bitai/sw/bitai/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/bitai/sw/bitai/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/bitai/sw/bitai/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
history = model.fit(X, y, epochs=1000, batch_size=5)
# Out:
# WARNING:tensorflow:From /home/bitai/sw/bitai/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/1000
# 300/300 [==============================] - 0s 529us/step - loss: 0.4706
# Epoch 2/1000
# 300/300 [==============================] - 0s 100us/step - loss: 0.3643
# Epoch 3/1000
# 300/300 [==============================] - 0s 106us/step - loss: 0.3032
# Epoch 4/1000
# 300/300 [==============================] - 0s 118us/step - loss: 0.2664
# Epoch 5/1000
# 300/300 [==============================] - 0s 107us/step - loss: 0.2432
# Epoch 6/1000
# 300/300 [==============================] - 0s 116us/step - loss: 0.2279
# Epoch 7/1000
# 300/300 [==============================] - 0s 120us/step - loss: 0.2180
# Epoch 8/1000
# 300/300 [==============================] - 0s 131us/step - loss: 0.2107
# Epoch 9/1000
# ...

# %%
print(history.history)
# Out:
# {'loss': [0.47056059588988625, 0.3642972399791082, 0.3032221458852291, 0.2663911291708549, 0.24316976877550284, 0.22786759802450737, 0.2179636595149835, 0.21068439049025375, 0.20513932251681885, 0.2028988437106212, 0.19955428497244915, 0.19702475896726052, 0.19323531289895376, 0.19199130733807881, 0.19067105706781148, 0.18954877437402803, 0.18730390115330617, 0.18536592349410058, 0.18530196544403832, 0.18198991231620312, 0.18083260722147923, 0.17931579919531943, 0.1767339862883091, 0.1770813997214039, 0.17545822099782526, 0.17417843686416745, 0.17320183051439622, 0.1707380902953446, 0.16981250842412313, 0.16548758953188855, 0.16755075350714227, 0.16355704333012303, 0.16209336921262243, 0.160554921021685, 0.16017290314969918, 0.15747658802817266, 0.15721356105059386, 0.1557512300244222, 0.1535903970555713, 0.1518855584319681, 0.1498425866321971, 0.14948374571589132, 0.14847600199282168, 0.1444550777009378, 0.1432232488024359, 0.14308148679944377, 0.14145912040645878, 0.140012706055616
# ...

# %%
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Loop')
plt.show()

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                840
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                410
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# ...
# Total params: 1,481
# Trainable params: 1,481
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import matplotlib.patches as mpatches
from sklearn.datasets import make_blobs, make_circles

def plot_data(pl, X, y):
    pl.plot(X[y == 0, 0], X[y == 0, 1], 'ob', alpha = 0.5)
    pl.plot(X[y == 1, 0], X[y == 1, 1], 'xr', alpha = 0.5)
    pl.legend(['0', '1'])
    return pl

# %%
X, y = make_circles(n_samples = 400, factor = 0.6, noise = 0.1, random_state = 42)
pl = plot_data(plt, X, y)
pl.show()

# %%
seed = 1
print("X size =", X.shape)
print("y size =", y.shape)
print("Num of Samples =", X.shape[0])
print(X)
# Out:
# X size = (400, 2)
# y size = (400,)
# Num of Samples = 400
# [[ 5.22047667e-01  2.45076964e-01]
#  [-4.90174568e-01  4.04540597e-01]
#  [ 4.69901235e-01  9.04544287e-01]
#  [ 7.37010889e-01  1.11486553e-01]
#  [-9.86636209e-01  1.69521513e-01]
#  [-7.17008501e-01  4.38359514e-01]
#  [-4.41013452e-01 -5.31920699e-01]
#  [-9.95858989e-01  1.08030813e-01]
#  [-3.25897203e-01  5.41504194e-01]
#  [-6.96094447e-01 -6.45797770e-01]
#  [ 9.28358178e-01  2.58529455e-01]
#  [ 2.30348927e-01 -3.40047801e-01]
#  [-2.66141506e-01  1.17464969e+00]
#  [-7.55781307e-01  7.93410286e-01]
#  [-5.69765424e-01 -9.25855019e-01]
#  [ 3.18599125e-01  1.02857282e+00]
#  [-5.10432759e-01  1.73074993e-01]
#  [ 3.95376430e-01 -3.96807852e-01]
#  [ 3.37431388e-01  5.71841873e-01]
#  [ 7.27958177e-01 -2.31006816e-01]
#  [-6.93334233e-01  6.76130038e-01]
#  [ 1.00825010e+00  5.07130501e-01]
#  [ 6.51086779e-01  1.35010193e-02]
#  [-3.45045802e-01  4.46996781e-01]
#  [ 1.04462893e+00  1.13624232e-01]
# ...

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
np.random.seed(seed)
mod = Sequential()
mod.add(Dense(1, activation = 'sigmoid', input_dim = 2))
mod.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
mod.fit(X, y, batch_size = 5, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 400/400 [==============================] - 0s 285us/step - loss: 0.7240
# Epoch 2/100
# 400/400 [==============================] - 0s 85us/step - loss: 0.7203
# Epoch 3/100
# 400/400 [==============================] - 0s 86us/step - loss: 0.7170
# Epoch 4/100
# 400/400 [==============================] - 0s 87us/step - loss: 0.7141
# Epoch 5/100
# 400/400 [==============================] - 0s 89us/step - loss: 0.7115
# Epoch 6/100
# 400/400 [==============================] - 0s 84us/step - loss: 0.7093
# Epoch 7/100
# 400/400 [==============================] - 0s 86us/step - loss: 0.7072
# Epoch 8/100
# 400/400 [==============================] - 0s 83us/step - loss: 0.7055
# Epoch 9/100
# 400/400 [==============================] - 0s 82us/step - loss: 0.7039
# Epoch 10/100
# 400/400 [==============================] - 0s 85us/step - loss: 0.7026
# Epoch 11/100
# 400/400 [==============================] - 0s 80us/step - loss: 0.7015
# Epoch 12/100
# ...

# %%
def pcu(mod, X, y):
    amin, bmin = X.min(axis = 0) - 0.1
    amax, bmax = X.max(axis = 0) + 0.1
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    c = mod.predict(ab)
    Z = c.reshape(aa.shape)
    plt.contourf(aa, bb, Z, cmap = 'bwr', alpha = 0.2)
    plot_data(plt, X, y)
    return plt

# %%
pcu(mod, X, y)
plt.title("L")
# Out:
# Text(0.5, 1.0, 'L')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
np.random.seed(seed)
mod = Sequential()
mod.add(Dense(3, activation = 'relu', input_dim = 2))
mod.add(Dense(1, activation = 'sigmoid'))
mod.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
mod.fit(X, y, batch_size = 5, epochs = 200, verbose = 1)
# Out:
# Epoch 1/200
# 400/400 [==============================] - 0s 345us/step - loss: 0.7000
# Epoch 2/200
# 400/400 [==============================] - 0s 88us/step - loss: 0.6968
# Epoch 3/200
# 400/400 [==============================] - 0s 88us/step - loss: 0.6945
# Epoch 4/200
# 400/400 [==============================] - 0s 91us/step - loss: 0.6927
# Epoch 5/200
# 400/400 [==============================] - 0s 88us/step - loss: 0.6909
# Epoch 6/200
# 400/400 [==============================] - 0s 89us/step - loss: 0.6895
# Epoch 7/200
# 400/400 [==============================] - 0s 89us/step - loss: 0.6881
# Epoch 8/200
# 400/400 [==============================] - 0s 88us/step - loss: 0.6869
# Epoch 9/200
# 400/400 [==============================] - 0s 99us/step - loss: 0.6857
# Epoch 10/200
# 400/400 [==============================] - 0s 156us/step - loss: 0.6847
# Epoch 11/200
# 400/400 [==============================] - 0s 281us/step - loss: 0.6838
# Epoch 12/200
# ...

# %%
pcu(mod, X, y)
plt.title("HL3(tanh)")
# Out:
# Text(0.5, 1.0, 'HL3(tanh)')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

np.random.seed(seed)

model = Sequential()

model.add(Dense(6, activation = 'relu', input_dim = 2))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

model.fit(X, y, batch_size = 5, epochs = 200, verbose = 1)
# Out:
# Epoch 1/200
# 400/400 [==============================] - 0s 383us/step - loss: 0.7748
# Epoch 2/200
# 400/400 [==============================] - 0s 106us/step - loss: 0.7506
# Epoch 3/200
# 400/400 [==============================] - 0s 93us/step - loss: 0.7369
# Epoch 4/200
# 400/400 [==============================] - 0s 92us/step - loss: 0.7283
# Epoch 5/200
# 400/400 [==============================] - 0s 91us/step - loss: 0.7219
# Epoch 6/200
# 400/400 [==============================] - 0s 90us/step - loss: 0.7170
# Epoch 7/200
# 400/400 [==============================] - 0s 89us/step - loss: 0.7125
# Epoch 8/200
# 400/400 [==============================] - 0s 89us/step - loss: 0.7083
# Epoch 9/200
# 400/400 [==============================] - 0s 89us/step - loss: 0.7038
# Epoch 10/200
# 400/400 [==============================] - 0s 89us/step - loss: 0.6991
# Epoch 11/200
# 400/400 [==============================] - 0s 93us/step - loss: 0.6956
# Epoch 12/200
# ...

# %%
pcu(mod, X, y)
plt.title("HL 3(tanh)")
# Out:
# Text(0.5, 1.0, 'HL 3(tanh)')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

np.random.seed(seed)

model = Sequential()

model.add(Dense(6, activation = 'relu', input_dim = 2))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

model.fit(X, y, batch_size = 5, epochs = 500, verbose = 1)
# Out:
# Epoch 1/500
# 400/400 [==============================] - 0s 415us/step - loss: 0.7748
# Epoch 2/500
# 400/400 [==============================] - 0s 95us/step - loss: 0.7506
# Epoch 3/500
# 400/400 [==============================] - 0s 115us/step - loss: 0.7369
# Epoch 4/500
# 400/400 [==============================] - 0s 124us/step - loss: 0.7283
# Epoch 5/500
# 400/400 [==============================] - 0s 132us/step - loss: 0.7219
# Epoch 6/500
# 400/400 [==============================] - 0s 133us/step - loss: 0.7170
# Epoch 7/500
# 400/400 [==============================] - 0s 163us/step - loss: 0.7125
# Epoch 8/500
# 400/400 [==============================] - 0s 167us/step - loss: 0.7083
# Epoch 9/500
# 400/400 [==============================] - 0s 168us/step - loss: 0.7038
# Epoch 10/500
# 400/400 [==============================] - 0s 167us/step - loss: 0.6991
# Epoch 11/500
# 400/400 [==============================] - 0s 166us/step - loss: 0.6957
# Epoch 12/500
# ...

# %%
pcu(mod, X, y)
plt.title("HL 6(tanh)")
# Out:
# Text(0.5, 1.0, 'HL 6(tanh)')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

np.random.seed(seed)

model = Sequential()

model.add(Dense(6, activation = 'relu', input_dim = 2))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

model.fit(X, y, batch_size = 5, epochs = 500, verbose = 1)
# Out:
# Epoch 1/500
# 400/400 [==============================] - 0s 434us/step - loss: 0.7748
# Epoch 2/500
# 400/400 [==============================] - 0s 100us/step - loss: 0.7506
# Epoch 3/500
# 400/400 [==============================] - 0s 108us/step - loss: 0.7369
# Epoch 4/500
# 400/400 [==============================] - 0s 117us/step - loss: 0.7283
# Epoch 5/500
# 400/400 [==============================] - 0s 138us/step - loss: 0.7219
# Epoch 6/500
# 400/400 [==============================] - 0s 138us/step - loss: 0.7170
# Epoch 7/500
# 400/400 [==============================] - 0s 160us/step - loss: 0.7125
# Epoch 8/500
# 400/400 [==============================] - 0s 203us/step - loss: 0.7083
# Epoch 9/500
# 400/400 [==============================] - 0s 237us/step - loss: 0.7038
# Epoch 10/500
# 400/400 [==============================] - 0s 291us/step - loss: 0.6991
# Epoch 11/500
# 400/400 [==============================] - 0s 301us/step - loss: 0.6957
# Epoch 12/500
# ...

# %%
c = 0
for opt in range(len(optimizers)):
    for active in range(len(activations)):
        print("activation =", activations[active])
        print("optimizer =", optimizers[opt])
        print("Test Accuracy =", results[c].mean())
        c += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-867370d75f98> in <module>
#       1 c = 0
# ----> 2 for opt in range(len(optimizers)):
#       3     for active in range(len(activations)):
#       4         print("activation =", activations[active])
#       5         print("optimizer =", optimizers[opt])
#
# NameError: name 'optimizers' is not defined
